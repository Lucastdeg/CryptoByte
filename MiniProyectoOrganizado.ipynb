# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# # Cargamos los Datos

# %% [markdown]
# # Bitcoin

# %%
df_bit = pd.read_csv('bitcoin.csv')
df_bit['date']= pd.to_datetime(df_bit['date'])
df_bit.info()
df_bit.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3358 entries, 0 to 3357
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3358 non-null   datetime64[ns]
#  1   price         3358 non-null   float64
#  2   total_volume  3358 non-null   float64
#  3   market_cap    3358 non-null   object
#  4   coin_name     3357 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 131.3+ KB
#         date    price  total_volume  market_cap coin_name
# 0 2015-01-01  313.992  4.699936e+07  4293958347   bitcoin
# 1 2015-01-02  314.446  3.885591e+07  4301448335   bitcoin
# 2 2015-01-03  286.572  1.187789e+08  3921358112   bitcoin
# 3 2015-01-04  260.936  2.055001e+08  3571639781   bitcoin
# 4 2015-01-05  273.220  1.550381e+08  3740880427   bitcoin

# %% [markdown]
# date (fecha): Esta columna representa la fecha en la que se registraron los datos. Está en formato datetime64, lo que significa que cada entrada de esta columna es una fecha específica con año, mes, día y posiblemente también hora.
#
# price(precio): Aquí se registra el precio de la criptomoneda Bitcoin en la fecha correspondiente. Por ejemplo, el primer registro indica que el precio de Bitcoin el 1 de enero de 2015 fue de aproximadamente 313.992 dólares.
#
# total_volume (volumen total): Esta columna muestra el volumen total de transacciones de Bitcoin realizadas en la fecha dada. Está expresado en una notación numérica (por ejemplo, 4.699936e+07), que representa un número grande utilizando la notación científica.
#
# market_cap (capitalización de mercado): Aquí se registra la capitalización de mercado de Bitcoin en la fecha correspondiente. La capitalización de mercado es el valor total de todas las unidades de una criptomoneda en circulación, calculada multiplicando el precio por la cantidad total de monedas en circulación.

# %% [markdown]
# ####  La proporción se calcula dividiendo el volumen total entre la capitalización de mercado y multiplicando por 100 para el porcentaje .

# %%
df_eth['market_cap'] = pd.to_numeric(df_eth['market_cap'], errors='coerce')
df_bit['proporcion'] = df_bit['total_volume'] / df_bit['market_cap'] * 100
df_bit.info()
df_bit.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3358 entries, 0 to 3357
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3358 non-null   datetime64[ns]
#  1   price         3358 non-null   float64
#  2   total_volume  3358 non-null   float64
#  3   market_cap    1307 non-null   float64
#  4   coin_name     3357 non-null   object
#  5   proporcion    1307 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 157.5+ KB
#         date    price  total_volume    market_cap coin_name  proporcion
# 0 2015-01-01  313.992  4.699936e+07  0.000000e+00   bitcoin         inf
# 1 2015-01-02  314.446  3.885591e+07  0.000000e+00   bitcoin         inf
# 2 2015-01-03  286.572  1.187789e+08  0.000000e+00   bitcoin         inf
# 3 2015-01-04  260.936  2.055001e+08  3.276463e+07   bitcoin  627.201173
# 4 2015-01-05  273.220  1.550381e+08  7.171054e+07   bitcoin  216.199919

# %% [markdown]
# # ~ Grafica Bitcoin ~

# %%
plt.figure(figsize=(11, 6))

plt.plot(df_bit['date'], df_bit['proporcion'], color='blue', linestyle='-', linewidth=1)

plt.xlabel('Fecha')
plt.ylabel('Proporción (Volumen / Capitalización)')
plt.title('Proporción Volumen/Capitalización a lo largo del Tiempo')

plt.xticks(rotation=45)

plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Ethereum

# %%
df_eth= pd.read_csv('ethereum.csv')
df_eth['date'] = pd.to_datetime(df_eth['date'])
df_eth['market_cap'] = pd.to_numeric(df_eth['market_cap'], errors='coerce')
df_eth['proporcion'] = df_eth['total_volume'] / df_eth['market_cap']* 100
df_eth.info()
df_eth.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3140 non-null   datetime64[ns]
#  1   price         3140 non-null   float64
#  2   total_volume  3140 non-null   float64
#  3   market_cap    3139 non-null   float64
#  4   coin_name     3140 non-null   object
#  5   proporcion    3139 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 147.3+ KB
#         date     price  total_volume    market_cap coin_name  proporcion
# 0 2015-08-07  2.831620  9.062200e+04  0.000000e+00  ethereum         inf
# 1 2015-08-08  1.330750  3.680700e+05  8.033948e+07  ethereum    0.458143
# 2 2015-08-10  0.687586  4.004641e+05  4.155631e+07  ethereum    0.963666
# 3 2015-08-11  1.067379  1.518998e+06  6.453901e+07  ethereum    2.353613
# 4 2015-08-12  1.256613  2.073893e+06  7.601326e+07  ethereum    2.728331

# %% [markdown]
# # ~ Grafica Ethereum ~

# %%
plt.figure(figsize=(11, 6))

plt.plot(df_eth['date'], df_eth['proporcion'], color='blue', linestyle='-', linewidth=1)

plt.xlabel('Fecha')
plt.ylabel('Proporción (Volumen / Capitalización)')
plt.title('Proporción Volumen/Capitalización a lo largo del Tiempo')

plt.xticks(rotation=45)

plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Tether

# %%
df_tet = pd.read_csv('tether.csv')
df_tet['date'] = pd.to_datetime(df_tet['date'])
df_tet['market_cap'] = pd.to_numeric(df_tet['market_cap'], errors='coerce')
df_tet['proporcion'] = df_tet['total_volume'] / df_tet['market_cap']* 100
df_tet.info()
df_tet.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3281 entries, 0 to 3280
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3281 non-null   datetime64[ns]
#  1   price         3281 non-null   float64
#  2   total_volume  3281 non-null   float64
#  3   market_cap    3281 non-null   float64
#  4   coin_name     3281 non-null   object
#  5   proporcion    3281 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 153.9+ KB
#         date     price  total_volume  market_cap coin_name  proporcion
# 0 2015-02-25  1.210160           5.0    304476.0    tether    0.001642
# 1 2015-03-02  0.572521           2.0    144046.0    tether    0.001388
# 2 2015-03-06  1.000000          50.0    251600.0    tether    0.019873
# 3 2015-03-07  1.000000       58196.0    251600.0    tether   23.130366
# 4 2015-03-08  1.000000          31.0    251600.0    tether    0.012321

# %% [markdown]
# # ~ Grafica Tether ~

# %%
plt.figure(figsize=(11, 6))

plt.plot(df_tet['date'], df_tet['proporcion'], color='blue', linestyle='-', linewidth=1)

plt.xlabel('Fecha')
plt.ylabel('Proporción (Volumen / Capitalización)')
plt.title('Proporción Volumen/Capitalización a lo largo del Tiempo')

plt.xticks(rotation=45)

plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Solana

# %%
df_sol = pd.read_csv('solana.csv')
df_sol['date'] = pd.to_datetime(df_sol['date'])
df_sol['market_cap'] = pd.to_numeric(df_sol['market_cap'], errors='coerce')
df_sol['proporcion'] = df_sol['total_volume'] / df_sol['market_cap']* 100
df_sol.info()
df_sol.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1432 entries, 0 to 1431
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1432 non-null   datetime64[ns]
#  1   price         1432 non-null   float64
#  2   total_volume  1432 non-null   float64
#  3   market_cap    1432 non-null   float64
#  4   coin_name     1432 non-null   object
#  5   proporcion    1432 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 67.3+ KB
#         date     price  total_volume    market_cap coin_name   proporcion
# 0 2020-04-11  0.957606  9.267267e+07  7.827652e+06    solana  1183.914010
# 1 2020-04-12  0.784711  4.945869e+07  6.173608e+06    solana   801.131129
# 2 2020-04-13  0.875994  3.782101e+07  7.269680e+06    solana   520.256842
# 3 2020-04-14  0.786712  1.957921e+07  6.302364e+06    solana   310.664608
# 4 2020-04-15  0.666673  1.752353e+07  5.306221e+06    solana   330.245062

# %% [markdown]
# # ~ Grafica Solana ~

# %%
plt.figure(figsize=(11, 6))

plt.plot(df_sol['date'], df_sol['proporcion'], color='blue', linestyle='-', linewidth=1)

plt.xlabel('Fecha')
plt.ylabel('Proporción (Volumen / Capitalización)')
plt.title('Proporción Volumen/Capitalización a lo largo del Tiempo')

plt.xticks(rotation=45)

plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Cardano

# %%
df_car = pd.read_csv('cardano.csv')
df_car['date'] = pd.to_datetime(df_car['date'])
df_car['market_cap'] = pd.to_numeric(df_car['market_cap'], errors='coerce')
df_car['proporcion'] = df_car['total_volume'] / df_car['market_cap']* 100
df_car.info()
df_car.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2338 entries, 0 to 2337
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2338 non-null   datetime64[ns]
#  1   price         2338 non-null   float64
#  2   total_volume  2338 non-null   float64
#  3   market_cap    2338 non-null   float64
#  4   coin_name''   2338 non-null   object
#  5   proporcion    2338 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 109.7+ KB
#         date     price  total_volume    market_cap coin_name''  proporcion
# 0 2017-10-18  0.026845  2.351678e+06  6.960214e+08     cardano    0.337874
# 1 2017-10-19  0.026830  2.815156e+06  6.956220e+08     cardano    0.404696
# 2 2017-10-20  0.030300  8.883473e+06  7.855800e+08     cardano    1.130817
# 3 2017-10-21  0.028588  5.308857e+06  7.412021e+08     cardano    0.716250
# 4 2017-10-22  0.027796  2.901876e+06  7.206698e+08     cardano    0.402664

# %% [markdown]
# # ~ Grafica Cardano ~

# %%
plt.figure(figsize=(11, 6))

plt.plot(df_car['date'], df_car['proporcion'], color='blue', linestyle='-', linewidth=1)

plt.xlabel('Fecha')
plt.ylabel('Proporción (Volumen / Capitalización)')
plt.title('Proporción Volumen/Capitalización a lo largo del Tiempo')

plt.xticks(rotation=45)

plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # The-sandbox

# %%
df_sand = pd.read_csv('the-sandbox.csv')
df_sand['date']= pd.to_datetime(df_sand['date'])
df_sand['market_cap'] = pd.to_numeric(df_sand['market_cap'], errors='coerce')
df_sand['proporcion'] = df_sand['total_volume'] / df_sand['market_cap']* 100
df_sand.info()
df_sand.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1307 entries, 0 to 1306
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1307 non-null   datetime64[ns]
#  1   price         1307 non-null   float64
#  2   total_volume  1307 non-null   float64
#  3   market_cap    1307 non-null   float64
#  4   coin_name     1307 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 51.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1307 entries, 0 to 1306
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1307 non-null   datetime64[ns]
#  1   price         1307 non-null   float64
#  2   total_volume  1307 non-null   float64
#  3   market_cap    1307 non-null   float64
#  4   coin_name     1307 non-null   object
#  5   proporcion    1307 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 61.4+ KB
#         date     price  total_volume    market_cap    coin_name  proporcion
# 0 2020-08-14  0.080920  3.841302e+07  0.000000e+00  the-sandbox         inf
# 1 2020-08-15  0.066403  1.410560e+08  0.000000e+00  the-sandbox         inf
# 2 2020-08-16  0.050784  4.315041e+07  0.000000e+00  the-sandbox         inf
# 3 2020-08-17  0.061080  3.370087e+07  3.276463e+07  the-sandbox  102.857481
# 4 2020-08-18  0.054974  1.621430e+07  7.171054e+07  the-sandbox   22.610762

# %% [markdown]
# # ~ Grafica The-sandbox ~

# %%
plt.figure(figsize=(11, 6))

plt.plot(df_sand['date'], df_sand['proporcion'], color='blue', linestyle='-', linewidth=1)

plt.xlabel('Fecha')
plt.ylabel('Proporción (Volumen / Capitalización)')
plt.title('Proporción Volumen/Capitalización a lo largo del Tiempo')

plt.xticks(rotation=45)

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(4)

axs[0].plot(df_bit['date'], df_bit['proporcion'])
axs[0].set_title('Bitcoin')

axs[1].plot(df_eth['date'], df_eth['proporcion'])
axs[1].set_title('Ethereum')

axs[2].plot(df_tet['date'], df_tet['proporcion'])
axs[2].set_title('Tether')

axs[3].plot(df_sol['date'], df_sol['proporcion'])
axs[3].set_title('Solana')

plt.tight_layout()

plt.show()
