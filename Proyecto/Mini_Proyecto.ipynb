# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df_alg = pd.read_csv('algorand.csv')
df_alg['date'] = pd.to_datetime(df_alg['date'])
df_alg.info()
df_alg.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1727 non-null   datetime64[ns]
#  1   price         1727 non-null   float64
#  2   total_volume  1727 non-null   float64
#  3   market_cap    1727 non-null   float64
#  4   coin_name     1727 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 67.6+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2019-06-21  1.604939  6.653181e+05  0.000000e+00  algorand
# 1 2019-06-22  3.172364  1.790331e+08  1.010855e+08  algorand
# 2 2019-06-23  2.159165  2.588226e+08  7.665618e+07  algorand
# 3 2019-06-24  1.899598  2.100211e+08  6.647512e+07  algorand
# 4 2019-06-25  1.409310  1.574706e+08  5.522254e+07  algorand

# %%
df_ape = pd.read_csv('apecoin.csv')
df_ape['date'] = pd.to_datetime(df_ape['date'])
df_ape.info()
df_ape.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 727 entries, 0 to 726
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          727 non-null    datetime64[ns]
#  1   price         727 non-null    float64
#  2   total_volume  727 non-null    float64
#  3   market_cap    727 non-null    float64
#  4   coin_name     727 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 28.5+ KB
#         date      price  total_volume    market_cap coin_name
# 0 2022-03-17   8.536839  1.455627e+09  9.460814e+08   apecoin
# 1 2022-03-18   8.536839  1.455627e+09  9.460814e+08   apecoin
# 2 2022-03-19  12.988729  5.214126e+09  1.740630e+09   apecoin
# 3 2022-03-20  11.535165  1.816680e+09  1.542255e+09   apecoin
# 4 2022-03-21   9.618214  1.381888e+09  1.261483e+09   apecoin

# %%
df_avl = pd.read_csv('avalanche-2.csv')
df_avl['date'] = pd.to_datetime(df_avl['date'])
df_avl.info()
df_avl.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1268 non-null   datetime64[ns]
#  1   price         1268 non-null   float64
#  2   total_volume  1268 non-null   float64
#  3   market_cap    1268 non-null   float64
#  4   coin_name     1268 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 49.7+ KB
#         date     price  total_volume    market_cap    coin_name
# 0 2020-09-22  5.284244  2.458573e+08  1.243579e+08  avalanche-2
# 1 2020-09-23  5.284244  2.458573e+08  1.243579e+08  avalanche-2
# 2 2020-09-24  3.491229  9.734243e+07  8.633525e+07  avalanche-2
# 3 2020-09-25  4.573891  6.966517e+07  1.122094e+08  avalanche-2
# 4 2020-09-26  4.702974  4.195075e+07  1.154319e+08  avalanche-2

# %%
df_axi = pd.read_csv('axie-infinity.csv')
df_axi['date'] = pd.to_datetime(df_axi['date'])
df_axi.info()
df_axi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225 entries, 0 to 1224
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1225 non-null   datetime64[ns]
#  1   price         1225 non-null   float64
#  2   total_volume  1225 non-null   float64
#  3   market_cap    1225 non-null   float64
#  4   coin_name     1225 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 48.0+ KB
#         date     price  total_volume    market_cap      coin_name
# 0 2020-11-04  0.145700  1.885524e+07  7.754756e+06  axie-infinity
# 1 2020-11-05  0.145700  1.885524e+07  7.754756e+06  axie-infinity
# 2 2020-11-06  0.134893  5.718030e+06  7.257185e+06  axie-infinity
# 3 2020-11-07  0.142960  3.529226e+06  7.678065e+06  axie-infinity
# 4 2020-11-08  0.141995  2.744359e+06  7.658840e+06  axie-infinity

# %%
df_bin = pd.read_csv('binancecoin.csv')
df_bin['date']= pd.to_datetime(df_bin['date'])
df_bin.info()
df_bin.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2368 entries, 0 to 2367
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2368 non-null   datetime64[ns]
#  1   price         2368 non-null   float64
#  2   total_volume  2368 non-null   float64
#  3   market_cap    2368 non-null   float64
#  4   coin_name     2368 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 92.6+ KB
#         date     price  total_volume    market_cap    coin_name
# 0 2017-09-16  0.107251      1.051223  1.072506e+07  binancecoin
# 1 2017-09-17  0.154041     14.678587  1.540413e+07  binancecoin
# 2 2017-09-18  0.173491      6.001767  1.734912e+07  binancecoin
# 3 2017-09-19  0.168334      3.878927  1.683342e+07  binancecoin
# 4 2017-09-20  0.166628     40.687619  1.666279e+07  binancecoin

# %%
df_binu = pd.read_csv('binance-usd.csv')
df_binu['date']=pd.to_datetime(df_binu['date'])
df_binu.info()
df_binu
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1635 entries, 0 to 1634
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1635 non-null   datetime64[ns]
#  1   price         1635 non-null   float64
#  2   total_volume  1635 non-null   float64
#  3   market_cap    1635 non-null   float64
#  4   coin_name     1635 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 64.0+ KB
#            date     price  total_volume    market_cap    coin_name
# 0    2019-09-21  1.000332  2.557694e+05  0.000000e+00  binance-usd
# 1    2019-09-22  1.000671  1.827058e+05  0.000000e+00  binance-usd
# 2    2019-09-23  0.999807  1.500765e+05  0.000000e+00  binance-usd
# 3    2019-09-24  0.999933  1.528188e+06  0.000000e+00  binance-usd
# 4    2019-09-25  1.002317  4.093715e+06  0.000000e+00  binance-usd
# ...         ...       ...           ...           ...          ...
# ...

# %%
df_btc = pd.read_csv('bitcoin.csv')
df_btc['date'] =pd.to_datetime(df_btc['date'])
df_btc.info()
df_btc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3358 entries, 0 to 3357
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3358 non-null   datetime64[ns]
#  1   price         3358 non-null   float64
#  2   total_volume  3358 non-null   float64
#  3   market_cap    3358 non-null   object
#  4   coin_name     3357 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 131.3+ KB
#         date    price  total_volume  market_cap coin_name
# 0 2015-01-01  313.992  4.699936e+07  4293958347   bitcoin
# 1 2015-01-02  314.446  3.885591e+07  4301448335   bitcoin
# 2 2015-01-03  286.572  1.187789e+08  3921358112   bitcoin
# 3 2015-01-04  260.936  2.055001e+08  3571639781   bitcoin
# 4 2015-01-05  273.220  1.550381e+08  3740880427   bitcoin

# %%
df_btc = df_btc.dropna()
df_btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3357 entries, 0 to 3357
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3357 non-null   datetime64[ns]
#  1   price         3357 non-null   float64
#  2   total_volume  3357 non-null   float64
#  3   market_cap    3357 non-null   object
#  4   coin_name     3357 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 157.4+ KB

# %%
x, y = df_btc['date'], df_btc['price']
plt.figure(figsize=(15,5))
plt.plot(x, y)

plt.show()

# %%
df_bit_cash = pd.read_csv('bitcoin-cash.csv')
df_bit_cash['date'] = pd.to_datetime(df_bit_cash['date'])
df_bit_cash.info()
df_bit_cash.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2415 entries, 0 to 2414
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2415 non-null   datetime64[ns]
#  1   price         2415 non-null   float64
#  2   total_volume  2415 non-null   float64
#  3   market_cap    2415 non-null   float64
#  4   coin_name     2415 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 94.5+ KB
#         date       price  total_volume    market_cap     coin_name
# 0 2017-08-02  767.767713  2.313604e+08  1.265448e+10  bitcoin-cash
# 1 2017-08-03  398.843862  1.480432e+08  6.573979e+09  bitcoin-cash
# 2 2017-08-04  234.618922  1.292868e+08  3.867188e+09  bitcoin-cash
# 3 2017-08-05  206.843373  1.093854e+08  3.409399e+09  bitcoin-cash
# 4 2017-08-06  216.019330  9.269142e+07  3.560825e+09  bitcoin-cash

# %%
df_car = pd.read_csv('cardano.csv')
df_car['date'] = pd.to_datetime(df_car['date'])
df_car.info()
df_car.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2338 entries, 0 to 2337
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2338 non-null   datetime64[ns]
#  1   price         2338 non-null   float64
#  2   total_volume  2338 non-null   float64
#  3   market_cap    2338 non-null   float64
#  4   coin_name''   2338 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 91.5+ KB
#         date     price  total_volume    market_cap coin_name''
# 0 2017-10-18  0.026845  2.351678e+06  6.960214e+08     cardano
# 1 2017-10-19  0.026830  2.815156e+06  6.956220e+08     cardano
# 2 2017-10-20  0.030300  8.883473e+06  7.855800e+08     cardano
# 3 2017-10-21  0.028588  5.308857e+06  7.412021e+08     cardano
# 4 2017-10-22  0.027796  2.901876e+06  7.206698e+08     cardano

# %%
df_cha = pd.read_csv('chain-2.csv')
df_cha['date'] = pd.to_datetime(df_cha['date'])
df_cha.info()
df_cha.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          729 non-null    datetime64[ns]
#  1   price         729 non-null    float64
#  2   total_volume  729 non-null    float64
#  3   market_cap    729 non-null    float64
#  4   coin_name     729 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 28.6+ KB
#         date     price  total_volume  market_cap coin_name
# 0 2022-03-15  0.052523  1.874287e+06         0.0   chain-2
# 1 2022-03-16  0.052523  1.874287e+06         0.0   chain-2
# 2 2022-03-17  0.055180  1.331913e+07         0.0   chain-2
# 3 2022-03-18  0.055856  1.601330e+07         0.0   chain-2
# 4 2022-03-19  0.057748  4.527954e+07         0.0   chain-2

# %%
df_chainlink = pd.read_csv('chainlink.csv')
df_chainlink['date'] = pd.to_datetime(df_chainlink['date'])
df_chainlink.info()
df_chainlink.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2316 entries, 0 to 2315
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2316 non-null   datetime64[ns]
#  1   price         2316 non-null   float64
#  2   total_volume  2316 non-null   float64
#  3   market_cap    2316 non-null   float64
#  4   coin_name     2316 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 90.6+ KB
#         date     price  total_volume    market_cap  coin_name
# 0 2017-11-09  0.225377  3.190026e+06  7.888183e+07  chainlink
# 1 2017-11-10  0.189036  2.121175e+06  6.616275e+07  chainlink
# 2 2017-11-11  0.181223  2.229298e+06  6.342793e+07  chainlink
# 3 2017-11-12  0.170013  5.361146e+06  5.950462e+07  chainlink
# 4 2017-11-13  0.180691  2.942234e+06  6.324186e+07  chainlink

# %%
df_chiliz = pd.read_csv('chiliz.csv')
df_chiliz['date'] = pd.to_datetime(df_chiliz['date'])
df_chiliz.info()
df_chiliz.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1716 entries, 0 to 1715
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1716 non-null   datetime64[ns]
#  1   price         1716 non-null   float64
#  2   total_volume  1716 non-null   float64
#  3   market_cap    1716 non-null   float64
#  4   coin_name     1716 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 67.2+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2019-07-02  0.017123  1.370848e+06  5.156286e+07    chiliz
# 1 2019-07-03  0.016304  4.552720e+05  4.909766e+07    chiliz
# 2 2019-07-04  0.011944  1.923948e+05  3.596619e+07    chiliz
# 3 2019-07-05  0.013802  2.252789e+05  4.156306e+07    chiliz
# 4 2019-07-06  0.015894  2.731453e+05  4.786372e+07    chiliz

# %%
df_cos = pd.read_csv('cosmos.csv')
df_cos['date'] = pd.to_datetime(df_cos['date'])
df_cos.info()
df_cos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1844 non-null   datetime64[ns]
#  1   price         1844 non-null   float64
#  2   total_volume  1844 non-null   float64
#  3   market_cap    1844 non-null   float64
#  4   coin_name     1844 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 72.2+ KB
#         date     price  total_volume  market_cap coin_name
# 0 2019-02-24  2.751586   9264.589772         0.0    cosmos
# 1 2019-02-25  3.002397    528.421839         0.0    cosmos
# 2 2019-02-26  3.740964  10766.494684         0.0    cosmos
# 3 2019-02-27  3.992312  13527.310484         0.0    cosmos
# 4 2019-02-28  3.528405   3560.407725         0.0    cosmos

# %%
df_crypto_chain = pd.read_csv('crypto-com-chain.csv')
df_crypto_chain['date'] = pd.to_datetime(df_crypto_chain['date'])
df_crypto_chain.info()
df_crypto_chain.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1897 entries, 0 to 1896
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1897 non-null   datetime64[ns]
#  1   price         1897 non-null   float64
#  2   total_volume  1897 non-null   float64
#  3   market_cap    1897 non-null   float64
#  4   coin_name     1897 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 74.2+ KB
#         date     price  total_volume  market_cap         coin_name
# 0 2019-01-02  0.021332  1.990475e+06         0.0  crypto-com-chain
# 1 2019-01-03  0.021255  1.968805e+06         0.0  crypto-com-chain
# 2 2019-01-04  0.021299  2.399313e+06         0.0  crypto-com-chain
# 3 2019-01-05  0.021462  2.393238e+06         0.0  crypto-com-chain
# 4 2019-01-06  0.018654  1.833583e+06         0.0  crypto-com-chain

# %%
df_dai = pd.read_csv('dai.csv')
df_dai['date'] = pd.to_datetime(df_dai['date'])
df_dai.info()
df_dai.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1576 entries, 0 to 1575
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1576 non-null   datetime64[ns]
#  1   price         1576 non-null   float64
#  2   total_volume  1576 non-null   float64
#  3   market_cap    1576 non-null   float64
#  4   coin_name     1576 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 61.7+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2019-11-19  1.000651  8.727642e+05  1.437646e+06       dai
# 1 2019-11-20  0.995411  4.841469e+06  6.945898e+06       dai
# 2 2019-11-21  0.991591  1.007820e+06  8.989928e+06       dai
# 3 2019-11-22  0.991102  3.679540e+06  1.249487e+07       dai
# 4 2019-11-23  0.992850  7.201905e+06  1.439175e+07       dai

# %%
df_dec = pd.read_csv('decentraland.csv')
df_dec['date'] = pd.to_datetime(df_dec['date'])
df_dec.info()
df_dec.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2326 entries, 0 to 2325
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2326 non-null   datetime64[ns]
#  1   price         2326 non-null   float64
#  2   total_volume  2326 non-null   float64
#  3   market_cap    2326 non-null   float64
#  4   coin_name     2326 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 91.0+ KB
#         date     price   total_volume    market_cap     coin_name
# 0 2017-10-28  0.010094  242118.083727  2.295129e+07  decentraland
# 1 2017-10-29  0.010124  295816.549841  2.301864e+07  decentraland
# 2 2017-10-30  0.009775  265963.623544  2.222603e+07  decentraland
# 3 2017-10-31  0.009237  275119.746609  2.100224e+07  decentraland
# 4 2017-11-01  0.010004  455564.189146  2.274761e+07  decentraland

# %%
df_dog = pd.read_csv('dogecoin.csv')
df_dog['date'] = pd.to_datetime(df_dog['date'])
df_dog.info()
df_dog.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3358 entries, 0 to 3357
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3358 non-null   datetime64[ns]
#  1   price         3358 non-null   float64
#  2   total_volume  3358 non-null   float64
#  3   market_cap    3357 non-null   float64
#  4   coin_name     3358 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 131.3+ KB
#         date     price   total_volume    market_cap coin_name
# 0 2015-01-01  0.000183  283845.500641  1.780332e+07  dogecoin
# 1 2015-01-02  0.000184  363741.739089  1.784733e+07  dogecoin
# 2 2015-01-03  0.000168  270052.236025  1.632320e+07  dogecoin
# 3 2015-01-04  0.000158  353697.860482  1.538501e+07  dogecoin
# 4 2015-01-05  0.000160  554935.735782  1.560247e+07  dogecoin

# %%
df_dog = df_dog.dropna()
df_dog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3357 entries, 0 to 3357
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3357 non-null   datetime64[ns]
#  1   price         3357 non-null   float64
#  2   total_volume  3357 non-null   float64
#  3   market_cap    3357 non-null   float64
#  4   coin_name     3357 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 157.4+ KB

# %%
df_eos= pd.read_csv('eos.csv')
df_eos['date'] = pd.to_datetime(df_eos['date'])
df_eos.info()
df_eos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2439 entries, 0 to 2438
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2439 non-null   datetime64[ns]
#  1   price         2439 non-null   float64
#  2   total_volume  2439 non-null   float64
#  3   market_cap    2439 non-null   float64
#  4   coin_name     2439 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 95.4+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2017-07-09  2.240472  1.481032e+07  4.473194e+08       eos
# 1 2017-07-10  1.642735  1.690991e+07  3.423681e+08       eos
# 2 2017-07-11  1.601147  1.908730e+07  3.369434e+08       eos
# 3 2017-07-12  1.997679  1.544467e+07  4.248519e+08       eos
# 4 2017-07-13  1.711524  7.032178e+06  3.668871e+08       eos

# %%
df_eth= pd.read_csv('ethereum.csv')
df_eth['date'] = pd.to_datetime(df_eth['date'])
df_eth.info()
df_eth.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3140 non-null   datetime64[ns]
#  1   price         3140 non-null   float64
#  2   total_volume  3140 non-null   float64
#  3   market_cap    3139 non-null   float64
#  4   coin_name     3140 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 122.8+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2015-08-07  2.831620  9.062200e+04  0.000000e+00  ethereum
# 1 2015-08-08  1.330750  3.680700e+05  8.033948e+07  ethereum
# 2 2015-08-10  0.687586  4.004641e+05  4.155631e+07  ethereum
# 3 2015-08-11  1.067379  1.518998e+06  6.453901e+07  ethereum
# 4 2015-08-12  1.256613  2.073893e+06  7.601326e+07  ethereum

# %%
df_eth = df_eth.dropna()
df_eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3139 entries, 0 to 3139
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3139 non-null   datetime64[ns]
#  1   price         3139 non-null   float64
#  2   total_volume  3139 non-null   float64
#  3   market_cap    3139 non-null   float64
#  4   coin_name     3139 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 147.1+ KB

# %%
df_eth_classic= pd.read_csv('ethereum-classic.csv')
df_eth_classic['date'] = pd.to_datetime(df_eth_classic['date'])
df_eth_classic.info()
df_eth_classic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2789 entries, 0 to 2788
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2789 non-null   datetime64[ns]
#  1   price         2789 non-null   float64
#  2   total_volume  2789 non-null   float64
#  3   market_cap    2789 non-null   float64
#  4   coin_name     2789 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 109.1+ KB
#         date     price  total_volume    market_cap         coin_name
# 0 2016-07-24  0.752345    11763300.0  0.000000e+00  ethereum-classic
# 1 2016-07-25  0.615038    10943600.0  5.061606e+07  ethereum-classic
# 2 2016-07-26  2.252580    47520200.0  1.853816e+08  ethereum-classic
# 3 2016-07-27  1.610000    63109100.0  1.324989e+08  ethereum-classic
# 4 2016-07-28  1.710000    40221600.0  1.407286e+08  ethereum-classic

# %%
df_file= pd.read_csv('filecoin.csv')
df_file['date'] = pd.to_datetime(df_file['date'])
df_file.info()
df_file.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1245 entries, 0 to 1244
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1245 non-null   datetime64[ns]
#  1   price         1245 non-null   float64
#  2   total_volume  1245 non-null   float64
#  3   market_cap    1245 non-null   float64
#  4   coin_name     1245 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 48.8+ KB
#         date      price  total_volume    market_cap coin_name
# 0 2020-10-15  61.038420  1.327082e+08  9.153586e+08  filecoin
# 1 2020-10-16  61.038420  1.327082e+08  9.153586e+08  filecoin
# 2 2020-10-17  44.776151  2.742888e+08  6.964481e+08  filecoin
# 3 2020-10-18  42.372713  9.880856e+07  6.856437e+08  filecoin
# 4 2020-10-19  32.711132  7.647548e+07  5.479410e+08  filecoin

# %%
df_frax= pd.read_csv('frax.csv')
df_frax['date'] = pd.to_datetime(df_frax['date'])
df_frax.info()
df_frax.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1178 entries, 0 to 1177
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1178 non-null   datetime64[ns]
#  1   price         1178 non-null   float64
#  2   total_volume  1178 non-null   float64
#  3   market_cap    1178 non-null   float64
#  4   coin_name     1178 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 46.1+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2020-12-21  0.975081  1.211742e+07  3.086958e+07      frax
# 1 2020-12-22  0.975081  1.211742e+07  3.086958e+07      frax
# 2 2020-12-23  1.001050  3.307647e+06  2.791435e+07      frax
# 3 2020-12-24  0.991596  2.465529e+06  2.561928e+07      frax
# 4 2020-12-25  0.999803  2.778573e+06  2.465650e+07      frax

# %%
df_ftx= pd.read_csv('ftx-token.csv')
df_ftx['date'] = pd.to_datetime(df_ftx['date'])
df_ftx.info()
df_ftx.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1688 entries, 0 to 1687
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1688 non-null   datetime64[ns]
#  1   price         1688 non-null   float64
#  2   total_volume  1688 non-null   float64
#  3   market_cap    1688 non-null   float64
#  4   coin_name     1688 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 66.1+ KB
#         date     price  total_volume  market_cap  coin_name
# 0 2019-07-30  1.645194  3.980676e+06         0.0  ftx-token
# 1 2019-07-31  1.868647  4.232132e+06         0.0  ftx-token
# 2 2019-08-01  1.714517  2.827412e+06         0.0  ftx-token
# 3 2019-08-02  1.762781  2.452565e+06         0.0  ftx-token
# 4 2019-08-03  1.787141  2.674472e+06         0.0  ftx-token

# %%
df_lido= pd.read_csv('lido-dao.csv')
df_lido['date'] = pd.to_datetime(df_lido['date'])
df_lido.info()
df_lido.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1163 entries, 0 to 1162
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1163 non-null   datetime64[ns]
#  1   price         1163 non-null   float64
#  2   total_volume  1163 non-null   float64
#  3   market_cap    1163 non-null   float64
#  4   coin_name     1163 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 45.6+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2021-01-05  1.750891  1.258283e+07  5.193326e+06  lido-dao
# 1 2021-01-06  1.750891  1.258283e+07  5.193326e+06  lido-dao
# 2 2021-01-07  1.760411  6.423586e+06  5.667692e+06  lido-dao
# 3 2021-01-08  1.426809  2.079384e+06  4.586996e+06  lido-dao
# 4 2021-01-09  1.495403  1.086875e+06  4.803312e+06  lido-dao

# %%
df_lite= pd.read_csv('litecoin.csv')
df_lite['date'] = pd.to_datetime(df_lite['date'])
df_lite.info()
df_lite.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3358 entries, 0 to 3357
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3358 non-null   datetime64[ns]
#  1   price         3358 non-null   float64
#  2   total_volume  3358 non-null   float64
#  3   market_cap    3357 non-null   float64
#  4   coin_name     3358 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 131.3+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2015-01-01  2.713621  1.382349e+06  9.559803e+07  litecoin
# 1 2015-01-02  2.679196  2.097774e+06  9.446229e+07  litecoin
# 2 2015-01-03  2.164153  1.575793e+07  7.636538e+07  litecoin
# 3 2015-01-04  1.939972  1.609468e+07  6.850770e+07  litecoin
# 4 2015-01-05  2.084590  1.232307e+07  7.366963e+07  litecoin

# %%
df_lite = df_lite.dropna()
df_lite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3357 entries, 0 to 3357
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3357 non-null   datetime64[ns]
#  1   price         3357 non-null   float64
#  2   total_volume  3357 non-null   float64
#  3   market_cap    3357 non-null   float64
#  4   coin_name     3357 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 157.4+ KB

# %%
df_matic= pd.read_csv('matic-network.csv')
df_matic['date'] = pd.to_datetime(df_matic['date'])
df_matic.info()
df_matic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1782 entries, 0 to 1781
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1782 non-null   datetime64[ns]
#  1   price         1782 non-null   float64
#  2   total_volume  1782 non-null   float64
#  3   market_cap    1782 non-null   float64
#  4   coin_name     1782 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 69.7+ KB
#         date     price  total_volume    market_cap      coin_name
# 0 2019-04-27  0.005470  4.315835e+07  1.159800e+07  matic-network
# 1 2019-04-28  0.005207  9.750768e+06  1.103852e+07  matic-network
# 2 2019-04-29  0.004381  8.388214e+06  9.288212e+06  matic-network
# 3 2019-04-30  0.003528  8.206900e+06  7.477598e+06  matic-network
# 4 2019-05-01  0.004396  2.399617e+07  9.332879e+06  matic-network

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-deep')
x, y = df_btc['date'], df_btc['price']
plt.figure(figsize=(15,5))
plt.plot(x, y, label='Bitcoin')
plt.grid(True)
plt.title('Bitcoin a lo largo de los años', fontsize=20)
plt.xlabel('Año', fontsize=15)
plt.ylabel('Precio', fontsize=15)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.style.use('seaborn-v0_8-deep')
plt.plot(df_eth['date'], df_eth['price'], label='Ethereum')
plt.title('Ethereum a lo largo de los años', fontsize=20)
plt.xlabel('Año', fontsize=15)
plt.ylabel('Precio', fontsize=15)
plt.grid(True)
plt.legend()
plt.show()

# %%
btc_2024 = df_btc[df_btc['date'].dt.year == 2024]
plt.plot(btc_2024['date'], btc_2024['price'])

# %%
btc_2024
# Out:
#            date        price  total_volume market_cap coin_name
# 3286 2024-01-01  42208.20218  1.418373e+10   8.28E+11   bitcoin
# 3287 2024-01-02  44168.68119  1.695900e+10   8.64E+11   bitcoin
# 3288 2024-01-03  44994.67389  3.908995e+10   8.78E+11   bitcoin
# 3289 2024-01-04  42821.55899  4.314616e+10   8.38E+11   bitcoin
# 3290 2024-01-05  44195.57856  2.612389e+10   8.66E+11   bitcoin
# ...         ...          ...           ...        ...       ...
# 3353 2024-03-08  66944.87639  4.885389e+10   1.32E+12   bitcoin
# 3354 2024-03-09  68315.25192  6.334659e+10   1.34E+12   bitcoin
# 3355 2024-03-10  68508.00396  2.135971e+10   1.35E+12   bitcoin
# 3356 2024-03-11  69075.66688  3.666054e+10   1.36E+12   bitcoin
# 3357 2024-03-12  72130.55301  6.665307e+10   1.42E+12   bitcoin
#
# [72 rows x 5 columns]

# %%
btc_2024['price'] = btc_2024['price'].diff(periods=1)
btc_2024
# Out:
# C:\Users\slope\AppData\Local\Temp\ipykernel_7796\1657836848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   btc_2024['price'] = btc_2024['price'].diff(periods=1)
#            date       price  total_volume market_cap coin_name
# 3286 2024-01-01         NaN  1.418373e+10   8.28E+11   bitcoin
# 3287 2024-01-02  1960.47901  1.695900e+10   8.64E+11   bitcoin
# 3288 2024-01-03   825.99270  3.908995e+10   8.78E+11   bitcoin
# 3289 2024-01-04 -2173.11490  4.314616e+10   8.38E+11   bitcoin
# 3290 2024-01-05  1374.01957  2.612389e+10   8.66E+11   bitcoin
# ...         ...         ...           ...        ...       ...
# 3353 2024-03-08   798.95711  4.885389e+10   1.32E+12   bitcoin
# ...

# %%
plt.figure(figsize=(15,8))
plt.style.use('seaborn-v0_8-deep')
plt.bar(btc_2024['date'], btc_2024['price'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=5))
plt.title('Cambios diarios de Bitcoin en 2024', fontsize=20)
plt.xlabel('Día', fontsize=15)
plt.ylabel('Cambio de precio', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df_chainlink['date'], df_chainlink['price'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df_eos['date'], df_eos['price'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df_lite['date'], df_lite['price'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df_matic['date'], df_matic['price'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df_frax['date'], df_frax['price'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df_chiliz['date'], df_chiliz['price'])
plt.show()

# %%
plt.style.use('seaborn-v0_8-deep')
plt.figure(figsize=(15,5))
plt.plot(df_dec['date'], df_dec['price'], label='Decentraland')
plt.plot(df_matic['date'], df_matic['price'], label='Matic')
plt.xlabel('Año', fontsize = 15)
plt.ylabel('Precio', fontsize = 15)
plt.title('Matic vs Decentraland', fontsize = 20)
plt.grid(True)
plt.legend(fontsize= 13)
plt.show()

# %%
df_shiba = pd.read_csv('shiba-inu.csv')
df_shiba['date']= pd.to_datetime(df_shiba['date'])
df_shiba.info()
df_shiba.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1306 entries, 0 to 1305
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1306 non-null   datetime64[ns]
#  1   price         1306 non-null   float64
#  2   total_volume  1306 non-null   float64
#  3   market_cap    1306 non-null   float64
#  4   coin_name     1306 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 51.1+ KB
#         date         price  total_volume  market_cap  coin_name
# 0 2020-08-01  9.722410e-10  1.426169e+06         0.0  shiba-inu
# 1 2020-08-02  9.722410e-10  1.426169e+06         0.0  shiba-inu
# 2 2020-08-03  5.169502e-10  1.773209e+05         0.0  shiba-inu
# 3 2020-08-04  1.471351e-10  5.897767e+04         0.0  shiba-inu
# 4 2020-08-05  1.635567e-10  1.892398e+04         0.0  shiba-inu

# %%
df_polka = pd.read_csv('polkadot.csv')
df_polka['date']= pd.to_datetime(df_polka['date'])
df_polka.info()
df_polka.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1302 non-null   datetime64[ns]
#  1   price         1302 non-null   float64
#  2   total_volume  1302 non-null   float64
#  3   market_cap    1302 non-null   float64
#  4   coin_name     1302 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 51.0+ KB
#            date      price  total_volume    market_cap coin_name
# 1297 2024-03-08  10.411939  5.917297e+08  1.393921e+10  polkadot
# 1298 2024-03-09  10.681233  6.243725e+08  1.430384e+10  polkadot
# 1299 2024-03-10  10.538196  4.600701e+08  1.411270e+10  polkadot
# 1300 2024-03-11  10.273129  3.982019e+08  1.375835e+10  polkadot
# 1301 2024-03-12  11.060673  7.404304e+08  1.483894e+10  polkadot

# %%
df_btc.describe()
# Out:
#                                 date         price  total_volume
# count                           3357   3357.000000  3.357000e+03
# mean   2019-08-07 17:56:14.798927616  15782.932408  1.709030e+10
# min              2015-01-01 00:00:00    172.147900  1.823845e+07
# 25%              2017-04-21 00:00:00   1263.045000  1.440330e+09
# 50%              2019-08-08 00:00:00   8824.592832  1.210275e+10
# 75%              2021-11-24 00:00:00  26729.137210  2.709931e+10
# max              2024-03-12 00:00:00  72130.553010  1.790000e+11
# std                              NaN  16878.415188  1.869699e+10

# %%
df_terra = pd.read_csv('terra-luna.csv')
df_terra['date']= pd.to_datetime(df_terra['date'])
df_terra.info()
df_terra.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1771 entries, 0 to 1770
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1771 non-null   datetime64[ns]
#  1   price         1771 non-null   float64
#  2   total_volume  1771 non-null   float64
#  3   market_cap    1771 non-null   float64
#  4   coin_name     1771 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 69.3+ KB
#         date     price  total_volume  market_cap   coin_name
# 0 2019-05-08  3.269977  6.703686e+06         0.0  terra-luna
# 1 2019-05-09  3.308075  1.060088e+07         0.0  terra-luna
# 2 2019-05-10  3.082165  3.371012e+07         0.0  terra-luna
# 3 2019-05-11  3.036930  8.852325e+05         0.0  terra-luna
# 4 2019-05-12  2.775900  9.426329e+05         0.0  terra-luna

# %%
plt.plot(df_terra['date'], df_terra['price'])
plt.figure()
plt.show()

# %%
plt.plot(df_car['date'], df_car['price'])
plt.figure()
plt.show()

# %%
plt.style.use('seaborn-v0_8-deep')
plt.figure(figsize=(15,5))
plt.plot(df_dec['date'], df_dec['price'], label='Decentraland')
plt.plot(df_matic['date'], df_matic['price'], label='Matic')
plt.plot(df_car['date'], df_car['price'], label='Cardano')
# plt.plot(df_chainlink['date'], df_chainlink['price'], label='Chainlink')
plt.xlabel('Año', fontsize = 15)
plt.ylabel('Precio', fontsize = 15)
plt.title('Matic vs Decentraland', fontsize = 20)
plt.grid(True)
plt.legend(fontsize= 13)
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(df_dog['date'], df_dog['price'])
plt.show()

# %%
df_tether = pd.read_csv('tether.csv')
df_tether['date']= pd.to_datetime(df_tether['date'])
df_tether.info()
df_tether.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3281 entries, 0 to 3280
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3281 non-null   datetime64[ns]
#  1   price         3281 non-null   float64
#  2   total_volume  3281 non-null   float64
#  3   market_cap    3281 non-null   float64
#  4   coin_name     3281 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 128.3+ KB
#         date     price  total_volume  market_cap coin_name
# 0 2015-02-25  1.210160           5.0    304476.0    tether
# 1 2015-03-02  0.572521           2.0    144046.0    tether
# 2 2015-03-06  1.000000          50.0    251600.0    tether
# 3 2015-03-07  1.000000       58196.0    251600.0    tether
# 4 2015-03-08  1.000000          31.0    251600.0    tether

# %%
plt.figure(figsize=(15, 5))
plt.plot(df_tether['date'], df_tether['price'])
plt.show()

# %%
df_sol = pd.read_csv('solana.csv')
df_sol['date']= pd.to_datetime(df_sol['date'])
df_sol.info()
df_sol.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1432 entries, 0 to 1431
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1432 non-null   datetime64[ns]
#  1   price         1432 non-null   float64
#  2   total_volume  1432 non-null   float64
#  3   market_cap    1432 non-null   float64
#  4   coin_name     1432 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 56.1+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2020-04-11  0.957606  9.267267e+07  7.827652e+06    solana
# 1 2020-04-12  0.784711  4.945869e+07  6.173608e+06    solana
# 2 2020-04-13  0.875994  3.782101e+07  7.269680e+06    solana
# 3 2020-04-14  0.786712  1.957921e+07  6.302364e+06    solana
# 4 2020-04-15  0.666673  1.752353e+07  5.306221e+06    solana

# %%
plt.figure(figsize=(15, 5))
plt.plot(df_sol['date'], df_sol['price'])
plt.show()

# %%
df_usd = pd.read_csv('usd-coin.csv')
df_usd['date']= pd.to_datetime(df_usd['date'])
df_usd.info()
df_usd.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1986 non-null   datetime64[ns]
#  1   price         1986 non-null   float64
#  2   total_volume  1986 non-null   float64
#  3   market_cap    1986 non-null   float64
#  4   coin_name     1986 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 77.7+ KB
#         date     price  total_volume  market_cap coin_name
# 0 2018-10-05  1.006242  31264.420430         0.0  usd-coin
# 1 2018-10-06  1.001530  20254.712255         0.0  usd-coin
# 2 2018-10-07  1.001177  49324.690669         0.0  usd-coin
# 3 2018-10-08  1.001906  47076.728142         0.0  usd-coin
# 4 2018-10-09  1.001983  55542.215509         0.0  usd-coin

# %%
plt.figure(figsize=(15, 5))
plt.plot(df_usd['date'], df_usd['price'])
plt.show()

# %%
df_tron = pd.read_csv('tron.csv')
df_tron['date']= pd.to_datetime(df_tron['date'])
df_tron.info()
df_tron.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2316 entries, 0 to 2315
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2316 non-null   datetime64[ns]
#  1   price         2316 non-null   float64
#  2   total_volume  2316 non-null   float64
#  3   market_cap    2316 non-null   float64
#  4   coin_name     2316 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 90.6+ KB
#         date     price  total_volume    market_cap coin_name
# 0 2017-11-09  0.002387  1.224287e+06  1.564042e+08      tron
# 1 2017-11-10  0.002044  9.904228e+05  1.339685e+08      tron
# 2 2017-11-11  0.001915  7.076430e+05  1.254706e+08      tron
# 3 2017-11-12  0.001804  8.147892e+05  1.182352e+08      tron
# 4 2017-11-13  0.002018  8.949856e+05  1.323864e+08      tron

# %%
plt.figure(figsize=(15, 5))
plt.plot(df_tron['date'], df_tron['price'])
plt.show()

# %%
df_sand = pd.read_csv('the-sandbox.csv')
df_sand['date']= pd.to_datetime(df_sand['date'])
df_sand.info()
df_sand.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1307 entries, 0 to 1306
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1307 non-null   datetime64[ns]
#  1   price         1307 non-null   float64
#  2   total_volume  1307 non-null   float64
#  3   market_cap    1307 non-null   float64
#  4   coin_name     1307 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 51.2+ KB
#         date     price  total_volume    market_cap    coin_name
# 0 2020-08-14  0.080920  3.841302e+07  0.000000e+00  the-sandbox
# 1 2020-08-15  0.066403  1.410560e+08  0.000000e+00  the-sandbox
# 2 2020-08-16  0.050784  4.315041e+07  0.000000e+00  the-sandbox
# 3 2020-08-17  0.061080  3.370087e+07  3.276463e+07  the-sandbox
# 4 2020-08-18  0.054974  1.621430e+07  7.171054e+07  the-sandbox

# %%
plt.style.use('seaborn-v0_8-deep')
plt.figure(figsize=(15,5))
plt.plot(df_dec['date'], df_dec['price'], label='Decentraland')
plt.plot(df_matic['date'], df_matic['price'], label='Matic')
plt.plot(df_car['date'], df_car['price'], label='Cardano')
plt.plot(df_sand['date'], df_sand['price'], label='Sandbox')
plt.xlabel('Año', fontsize = 15)
plt.ylabel('Precio', fontsize = 15)
plt.title('Matic vs Decentraland', fontsize = 20)
plt.grid(True)
plt.legend(fontsize= 13)
plt.show()

# %%
fig, axs = plt.subplots(4)


axs[0].plot(df_sand['date'], df_sand['price'])
axs[0].set_title('Sandbox')

axs[1].plot(df_dec['date'], df_dec['price'])
axs[1].set_title('Decentraland')

axs[2].plot(df_matic['date'], df_matic['price'])
axs[2].set_title('Matic')

axs[3].plot(df_car['date'], df_car['price'])
axs[3].set_title('Cardano')

plt.tight_layout()

plt.show()
